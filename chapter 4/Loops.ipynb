# %%
# Loops

# %%
# for Loop
magicians = ["Mage_A","Mage_B","Mage_C"]
for mage in magicians:
    print(mage)
# Out:
# Mage_A
# Mage_A, that was a great trick!
# Mage_B
# Mage_B, that was a great trick!
# Mage_C
# Mage_C, that was a great trick!

# %%
magicians = ["Mage_A","Mage_B","Mage_C"]
for mage in magicians:
    print(f"{mage.title()}, that was a great trick!")
# Out:
# Mage_A, that was a great trick!
# Mage_B, that was a great trick!
# Mage_C, that was a great trick!

# %%
for value in range(1,5):
    print(value)
# Out:
# 1
# 2
# 3
# 4

# %%
for value in range(6):
    print(value)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
num = list(range(1,6))
print(num)
# Out:
# [1, 2, 3, 4, 5]

# %%
even_numbers = list(range(2, 11, 2))
print(even_numbers)
# Out:
# [2, 4, 6, 8, 10]

# %%
squares = []
for value in range(1,11):
    squares.append(value ** 2)
print(squares)
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %%
squares = []        # Same functioning using insert
for value in range(1,11):
    squares.insert(10,value ** 2)
print(squares)
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %%
digits = list(range(1,11))
print(min(digits))
print(max(digits))
print(sum(digits))
# Out:
# 1
# 10
# 55

# %%
# List comprehension
squares = [value**2 for value in range(1,11)]
print(squares)
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %%
# Slicing the List
anime = ['Naruto','Gintama','Dragon ball','Beyblade']
print(anime[0:3])
print(anime[:3])
print(anime[2:])
print(anime[:-3])
print(anime[-3:])
print(anime[1:-1])
print(anime[0:3:2])
# Out:
# ['Naruto', 'Gintama', 'Dragon ball']
# ['Naruto', 'Gintama', 'Dragon ball']
# ['Dragon ball', 'Beyblade']
# ['Naruto']
# ['Gintama', 'Dragon ball', 'Beyblade']
# ['Gintama', 'Dragon ball']
# ['Naruto', 'Dragon ball']

# %%
players = ['charles', 'martina', 'michael', 'florence', 'eli']
print("Here are the first three players on my team:")
for player in players[:3]:
    print(player.title())
# Out:
# Here are the first three players on my team:
# Charles
# Martina
# Michael

# %%
# Copying Lists
my_foods = ['pizza', 'falafel', 'carrot cake']
friend_foods = my_foods[:]
# NOTE: if we write 
# friend_foods = my_foods , any changes made to my_foods will be reflected to friend_foods too cause 
# both are working on a single list
# To over come this we add [:] for copying the list
print("My favorite foods are:")
print(my_foods)
print("\nMy friend's favorite foods are:")
print(friend_foods)
# Out:
# My favorite foods are:
# ['pizza', 'falafel', 'carrot cake']
#
# My friend's favorite foods are:
# ['pizza', 'falafel', 'carrot cake']

# %%
my_foods = ['pizza', 'falafel', 'carrot cake']
friend_foods = my_foods[:]

my_foods.append('cannoli')
friend_foods.append('ice cream')

print(my_foods)
print(friend_foods)
# Out:
# ['pizza', 'falafel', 'carrot cake', 'cannoli']
# ['pizza', 'falafel', 'carrot cake', 'ice cream']

# %%
# tuple
rectangle = (200,50)
print(rectangle[0])
# Out:
# 200

# %%
# we can't change the value in tuple
rectangle[0] = 250
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 # we can't change the value in tuple
# ----> 2 rectangle[0] = 250
#
# TypeError: 'tuple' object does not support item assignment

# %%
my_t = (3,)
print(my_t)
# Out:
# (3,)

# %%
dimensions = (200, 50)
for dimension in dimensions:
    print(dimension)
# Out:
# 200
# 50

# %%
dimensions = (200, 50)  # Although we can't change the value in a tuple but we can assign a whole new value
# to the tuple like this
print("Original dimensions:")
for dimension in dimensions:
    print(dimension)
dimensions = (400, 100)
print("\nModified dimensions:")
for dimension in dimensions:
    print(dimension)
# Out:
# Original dimensions:
# 200
# 50
#
# Modified dimensions:
# 400
# 100
