# %%
# LISTS

# %%
bicycles = ['trek', 'cannondale', 'redline', 'specialized']
print(bicycles)
print(bicycles[0])
print(bicycles[0].title())
print(bicycles[-1])
# Out:
# ['trek', 'cannondale', 'redline', 'specialized']
# trek
# Trek
# specialized

# %%
message = f"My first bicycle was a {bicycles[0].title()}."
print(message)
# Out:
# My first bicycle was a Trek.

# %%
motorcycles = ['honda', 'yamaha', 'suzuki']
print(motorcycles)
motorcycles[0] = 'ducati'
print(motorcycles)
motorcycles.append('Royal Infield')
print(motorcycles)
# Out:
# ['honda', 'yamaha', 'suzuki']
# ['ducati', 'yamaha', 'suzuki']
# ['ducati', 'yamaha', 'suzuki', 'Royal Infield']

# %%
motorcycles = ['honda', 'yamaha', 'suzuki']
motorcycles.insert(0, 'ducati')
print(motorcycles)
# Out:
# ['ducati', 'honda', 'yamaha', 'suzuki']

# %%
motorcycles = ['honda', 'yamaha', 'suzuki']
del motorcycles[0]
print(motorcycles)
# Out:
# ['yamaha', 'suzuki']

# %%
motorcycles = ['honda', 'yamaha', 'suzuki']
print(motorcycles)

popped_motorcycle = motorcycles.pop()   # pop also returns the Item which was popped
print(motorcycles)
print(popped_motorcycle)
# Out:
# ['honda', 'yamaha', 'suzuki']
# ['honda', 'yamaha']
# suzuki

# %%
motorcycles = ['honda', 'yamaha', 'suzuki']
first_owned = motorcycles.pop(0)
print(f"The first motorcycle I owned was a {first_owned.title()}.")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[18], line 2
#       1 motorcycles = ['honda', 'yamaha', 'suzuki']
# ----> 2 first_owned = motorcycles.pop(3)
#       3 print(f"The first motorcycle I owned was a {first_owned.title()}.")
#
# IndexError: pop index out of range

# %%
motorcycles = ['honda', 'yamaha', 'suzuki', 'ducati']
print(motorcycles)
motorcycles.remove('ducati')    # removing by value
print(motorcycles)
# Out:
# ['honda', 'yamaha', 'suzuki', 'ducati']
# ['honda', 'yamaha', 'suzuki']

# %%
cars = ['bmw', 'audi', 'toyota', 'subaru']
cars.sort()     # sort() method changes the list permanently
print(cars)
cars.sort(reverse=True)
print(cars)
# Out:
# ['audi', 'bmw', 'subaru', 'toyota']
# ['toyota', 'subaru', 'bmw', 'audi']

# %%
cars = ['bmw', 'audi', 'toyota', 'subaru']

print("\nHere is the sorted list:")
print(sorted(cars,reverse = True))     # sorted() fn changes the list temporarily
print("\nHere is the original list:")
print(cars)
# Out:
# Here is the sorted list:
# ['toyota', 'subaru', 'bmw', 'audi']
#
# Here is the original list:
# ['bmw', 'audi', 'toyota', 'subaru']

# %%
cars = ['bmw', 'audi', 'toyota', 'subaru']
cars.reverse()
print(cars)
# Out:
# ['subaru', 'toyota', 'audi', 'bmw']

# %%
cars = ['bmw', 'audi', 'toyota', 'subaru']
print(f"Length of cars list: {len(cars)}")
# Out:
# Length of cars list: 4
