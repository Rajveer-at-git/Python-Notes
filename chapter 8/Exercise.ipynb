# %%
def book(btitle):
    print(f"{btitle.title()} is my favorite book.")

book('atomic habits')
# Out:
# Atomic Habits is my favorite book.

# %%
# Out:
# I have a hamster.
# My hamster's name is Harry.
#
# I have a Dog.
# My Dog's name is Jade.

# %%
# Out:
# I have a hamster.
# My hamster's name is Harry.

# %%
# Out:
# I have a dog.
# My dog's name is Willie.

# %%
# Out:
# I have a cat.
# My cat's name is Winnie.
