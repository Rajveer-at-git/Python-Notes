# %% [markdown]
# Github's API call for asking info about the most popular python repos.
# https://api.github.com/search/repositories?q=language:python+sort:stars
#
# https://api.github.com/ -> part of Github that responds to API calls
#
# search/repositories -> to conduct a search through all repos in github
#
# ? ->about to start an argument
#
# q= -> q means query, q= lets us begin specifying a query
#
# language:python -> primary language should be python
#
# +sort:stars -> sort ascending to the star marked on the repo

# %%
import requests

# Make an API call and check the response
url = "https://api.github.com/search/repositories"
url += "?q=language:python+sort:stars:>10000"

headers = {"Accept": "application/vnd.github.v3+json"}  # Use third version of API
r = requests.get(url, headers=headers)
print(f"Status code: {r.status_code}")

# Convert the response to a dicitionary
response_dict = r.json()

# Process results
print(response_dict.keys())
# Out:
# Status code: 200
# dict_keys(['total_count', 'incomplete_results', 'items'])

# %%
"""Print basic info about the repos"""
import requests

# Make an API call and check the response
url = "https://api.github.com/search/repositories"
url += "?q=language:python+stars:>10000"

headers = {"Accept": "application/vnd.github.v3+json"}  # Use third version of API
r = requests.get(url, headers=headers)
print(f"Status code: {r.status_code}")

# Convert the response to a dicitionary
response_dict = r.json()

print(f"Total repositories: {response_dict['total_count']}")
print(f"Complete results: {not response_dict['incomplete_results']}")

# Explore information about the repositories.
repo_dicts = response_dict['items']
print(f"Repositories returned: {len(repo_dicts)}")

# Examine the first repo
repo_dict = repo_dicts[0]
print(f"\nKeys: {len(repo_dict)}")
for key in sorted(repo_dict.keys()):
    print(key)
# Out:
# Status code: 200
# Total repositories: 935
# Complete results: True
# Repositories returned: 30
#
# Keys: 82
# allow_forking
# archive_url
# archived
# assignees_url
# blobs_url
# branches_url
# clone_url
# collaborators_url
# comments_url
# commits_url
# compare_url
# contents_url
# contributors_url
# created_at
# default_branch
# deployments_url
# description
# disabled
# downloads_url
# events_url
# fork
# forks
# forks_count
# forks_url
# full_name
# git_commits_url
# git_refs_url
# git_tags_url
# git_url
# has_discussions
# has_downloads
# has_issues
# has_pages
# has_projects
# has_pull_requests
# has_wiki
# homepage
# hooks_url
# html_url
# id
# is_template
# issue_comment_url
# issue_events_url
# issues_url
# keys_url
# labels_url
# language
# languages_url
# license
# merges_url
# milestones_url
# mirror_url
# name
# node_id
# notifications_url
# open_issues
# open_issues_count
# owner
# private
# pull_request_creation_policy
# pulls_url
# pushed_at
# releases_url
# score
# ...

# %%
"""Print details of the first repo"""

import requests

# Make an API call and check the response
url = "https://api.github.com/search/repositories"
url += "?q=language:python+stars:>10000"

headers = {"Accept": "application/vnd.github.v3+json"}  # Use third version of API
r = requests.get(url, headers=headers)
print(f"Status code: {r.status_code}")

# Convert the response to a dicitionary
response_dict = r.json()

print(f"Total repositories: {response_dict['total_count']}")
print(f"Complete results: {not response_dict['incomplete_results']}")

# Explore information about the repositories.
repo_dicts = response_dict['items']
print(f"Repositories returned: {len(repo_dicts)}")

# Examine the first repo
repo_dict = repo_dicts[0]
print(f"\nKeys: {len(repo_dict)}")
for key in sorted(repo_dict.keys()):
    print(key)

print("\nSelected information about first repository:")
print(f"Name: {repo_dict['name']}")
print(f"Owner: {repo_dict['owner']['login']}")
print(f"Stars: {repo_dict['stargazers_count']}")
print(f"Repository: {repo_dict['html_url']}")
print(f"Created: {repo_dict['created_at']}")
print(f"Updated: {repo_dict['updated_at']}")
print(f"Description: {repo_dict['description']}")
# Out:
# Status code: 200
# Total repositories: 935
# Complete results: True
# Repositories returned: 30
#
# Keys: 82
# allow_forking
# archive_url
# archived
# assignees_url
# blobs_url
# branches_url
# clone_url
# collaborators_url
# comments_url
# commits_url
# compare_url
# contents_url
# contributors_url
# created_at
# default_branch
# deployments_url
# description
# disabled
# downloads_url
# events_url
# fork
# forks
# forks_count
# forks_url
# full_name
# git_commits_url
# git_refs_url
# git_tags_url
# git_url
# has_discussions
# has_downloads
# has_issues
# has_pages
# has_projects
# has_pull_requests
# has_wiki
# homepage
# hooks_url
# html_url
# id
# is_template
# issue_comment_url
# issue_events_url
# issues_url
# keys_url
# labels_url
# language
# languages_url
# license
# merges_url
# milestones_url
# mirror_url
# name
# node_id
# notifications_url
# open_issues
# open_issues_count
# owner
# private
# pull_request_creation_policy
# pulls_url
# pushed_at
# releases_url
# score
# ...

# %%
"""Print details of each repo"""

import requests

# Make an API call and check the response
url = "https://api.github.com/search/repositories"
url += "?q=language:python+stars:>10000"

headers = {"Accept": "application/vnd.github.v3+json"}  # Use third version of API
r = requests.get(url, headers=headers)
print(f"Status code: {r.status_code}")

# Convert the response to a dicitionary
response_dict = r.json()

print(f"Total repositories: {response_dict['total_count']}")
print(f"Complete results: {not response_dict['incomplete_results']}")

# Explore information about the repositories.
repo_dicts = response_dict['items']
print(f"Repositories returned: {len(repo_dicts)}")

# Examine the first repo
repo_dict = repo_dicts[0]
print(f"\nKeys: {len(repo_dict)}")
for key in sorted(repo_dict.keys()):
    print(key)

print("\nSelected information about each repository:")
for repo_dict in repo_dicts:
    print(f"Name: {repo_dict['name']}")
    print(f"Owner: {repo_dict['owner']['login']}")
    print(f"Stars: {repo_dict['stargazers_count']}")
    print(f"Repository: {repo_dict['html_url']}")
    print(f"Created: {repo_dict['created_at']}")
    print(f"Updated: {repo_dict['updated_at']}")
    print(f"Description: {repo_dict['description']}")
# Out:
# Status code: 200
# Total repositories: 935
# Complete results: True
# Repositories returned: 30
#
# Keys: 82
# allow_forking
# archive_url
# archived
# assignees_url
# blobs_url
# branches_url
# clone_url
# collaborators_url
# comments_url
# commits_url
# compare_url
# contents_url
# contributors_url
# created_at
# default_branch
# deployments_url
# description
# disabled
# downloads_url
# events_url
# fork
# forks
# forks_count
# forks_url
# full_name
# git_commits_url
# git_refs_url
# git_tags_url
# git_url
# has_discussions
# has_downloads
# has_issues
# has_pages
# has_projects
# has_pull_requests
# has_wiki
# homepage
# hooks_url
# html_url
# id
# is_template
# issue_comment_url
# issue_events_url
# issues_url
# keys_url
# labels_url
# language
# languages_url
# license
# merges_url
# milestones_url
# mirror_url
# name
# node_id
# notifications_url
# open_issues
# open_issues_count
# owner
# private
# pull_request_creation_policy
# pulls_url
# pushed_at
# releases_url
# score
# ...

# %% [markdown]
# O/P:
#
# Status code: 200
# Total repositories: 934
# Complete results: True
# Repositories returned: 30
#
# Keys: 82
# allow_forking
# archive_url
# archived
# assignees_url
# blobs_url
# branches_url
# clone_url
# collaborators_url
# comments_url
# commits_url
# compare_url
# contents_url
# contributors_url
# created_at
# default_branch
# deployments_url
# description
# disabled
# downloads_url
# events_url
# fork
# forks
# forks_count
# forks_url
# full_name
# git_commits_url
# git_refs_url
# git_tags_url
# git_url
# has_discussions
# has_downloads
# has_issues
# has_pages
# has_projects
# has_pull_requests
# has_wiki
# homepage
# hooks_url
# html_url
# id
# is_template
# issue_comment_url
# issue_events_url
# issues_url
# keys_url
# labels_url
# language
# languages_url
# license
# merges_url
# milestones_url
# mirror_url
# name
# node_id
# notifications_url
# open_issues
# open_issues_count
# owner
# private
# pull_request_creation_policy
# pulls_url
# pushed_at
# releases_url
# score
# size
# ssh_url
# stargazers_count
# stargazers_url
# statuses_url
# subscribers_url
# subscription_url
# svn_url
# tags_url
# teams_url
# topics
# trees_url
# updated_at
# url
# visibility
# watchers
# watchers_count
# web_commit_signoff_required
#
# Selected information about each repository:
# Name: public-apis
# Owner: public-apis
# Stars: 440756
# Repository: https://github.com/public-apis/public-apis
# Created: 2016-03-20T23:49:42Z
# Updated: 2026-06-11T07:46:17Z
# Description: A collective list of free APIs
# Name: free-programming-books
# Owner: EbookFoundation
# Stars: 390077
# Repository: https://github.com/EbookFoundation/free-programming-books
# Created: 2013-10-11T06:50:37Z
# Updated: 2026-06-11T07:33:03Z
# Description: :books: Freely available programming books
# Name: system-design-primer
# Owner: donnemartin
# Stars: 352585
# Repository: https://github.com/donnemartin/system-design-primer
# Created: 2017-02-26T16:15:28Z
# Updated: 2026-06-11T07:42:23Z
# Description: Learn how to design large-scale systems. Prep for the system design interview.  Includes Anki flashcards.
# Name: awesome-python
# Owner: vinta
# Stars: 302325
# Repository: https://github.com/vinta/awesome-python
# Created: 2014-06-27T21:00:06Z
# Updated: 2026-06-11T07:25:54Z
# Description: An opinionated list of Python frameworks, libraries, tools, and resources
# Name: Python
# Owner: TheAlgorithms
# Stars: 221853
# Repository: https://github.com/TheAlgorithms/Python
# Created: 2016-07-16T09:44:01Z
# Updated: 2026-06-11T07:31:20Z
# Description: All Algorithms implemented in Python
# Name: hermes-agent
# Owner: NousResearch
# Stars: 190344
# Repository: https://github.com/NousResearch/hermes-agent
# Created: 2025-07-22T22:22:28Z
# Updated: 2026-06-11T07:46:30Z
# Description: The agent that grows with you
# Name: AutoGPT
# Owner: Significant-Gravitas
# Stars: 184890
# Repository: https://github.com/Significant-Gravitas/AutoGPT
# Created: 2023-03-16T09:21:07Z
# Updated: 2026-06-11T06:59:30Z
# Description: AutoGPT is the vision of accessible AI for everyone, to use and to build on. Our mission is to provide the tools, so that you can focus on what matters.
# Name: yt-dlp
# Owner: yt-dlp
# Stars: 169775
# Repository: https://github.com/yt-dlp/yt-dlp
# Created: 2020-10-26T04:22:55Z
# Updated: 2026-06-11T07:44:53Z
# Description: A feature-rich command-line audio/video downloader
# Name: stable-diffusion-webui
# Owner: AUTOMATIC1111
# Stars: 163610
# Repository: https://github.com/AUTOMATIC1111/stable-diffusion-webui
# Created: 2022-08-22T14:05:26Z
# Updated: 2026-06-11T07:34:55Z
# Description: Stable Diffusion web UI
# Name: transformers
# Owner: huggingface
# Stars: 161495
# Repository: https://github.com/huggingface/transformers
# Created: 2018-10-29T13:56:00Z
# Updated: 2026-06-11T07:16:36Z
Tensors and Dynamic neural networks in Python with strong GPU acceleration
# Name: fastapi
# Owner: fastapi
# Stars: 99102
# Repository: https://github.com/fastapi/fastapi
# Created: 2018-12-08T08:21:47Z
# Updated: 2026-06-11T07:03:18Z
# Description: FastAPI framework, high performance, easy to learn, fast to code, ready for production
# Name: browser-use
# Owner: browser-use
# Stars: 98227
# Repository: https://github.com/browser-use/browser-use
# Created: 2024-10-31T16:00:56Z
# Updated: 2026-06-11T07:44:49Z
# Description: 🌐 Make websites accessible for AI agents. Automate tasks online with ease.
# Name: thefuck
# Owner: nvbn
# Stars: 97316
# Repository: https://github.com/nvbn/thefuck
# Created: 2015-04-08T15:08:04Z
# Updated: 2026-06-11T06:47:35Z
# Description: Magnificent app which corrects your previous console command.
# Name: Deep-Live-Cam
# Owner: hacksider
# Stars: 93714
# Repository: https://github.com/hacksider/Deep-Live-Cam
# Created: 2023-09-24T13:19:31Z
# Updated: 2026-06-11T06:16:02Z
# Description: real time face swap and one-click video deepfake with only a single image
# Name: ui-ux-pro-max-skill
# Owner: nextlevelbuilder
# Stars: 90104
# Repository: https://github.com/nextlevelbuilder/ui-ux-pro-max-skill
# Created: 2025-11-30T11:36:31Z
# Updated: 2026-06-11T07:45:15Z
# Description: An AI SKILL that provide design intelligence for building professional UI/UX multiple platforms
# Name: django
# Owner: django
# Stars: 87828
# Repository: https://github.com/django/django
# Created: 2012-04-28T02:47:18Z
# Updated: 2026-06-11T06:35:42Z
# Description: The Web framework for perfectionists with deadlines.

# %%
"""Print details of each repo and make a visualization"""

import requests
import plotly.express as px

# Make an API call and check the response
url = "https://api.github.com/search/repositories"
url += "?q=language:python+stars:>10000"

headers = {"Accept": "application/vnd.github.v3+json"}  # Use third version of API
r = requests.get(url, headers=headers)
print(f"Status code: {r.status_code}")

# Process overall results
response_dict = r.json()
print(f"Complete results: {not response_dict['incomplete_results']}")

# Process repository information
repo_dicts = response_dict['items']
repo_names, stars, hover_texts = [], [], []
for repo_dict in repo_dicts:
    repo_names.append(repo_dict['name'])
    stars.append(repo_dict['stargazers_count'])

    # Build hover texts.
    owner = repo_dict['owner']['login']
    description = repo_dict['description']
    hover_text = f"{owner}<br />{description}"
    hover_texts.append(hover_text)

# Make visualization.
title = "Most-Starred Python Projects on GitHub"
labels = {'x': 'Repository', 'y': 'Stars'}
fig = px.bar(x=repo_names, y=stars, title=title, labels=labels,
            hover_name=hover_texts)
fig.update_layout(title_font_size=28, xaxis_title_font_size=20,
                yaxis_title_font_size=20)
fig.show()
# Out:
# Status code: 200
# Complete results: True

# %% [markdown]
# ##### Plotly uses HTML to create graphs, therefore we can add active links to the graphs

# %%
"""Make clickable-links in the Graph"""

import requests
import plotly.express as px

# Make an API call and check the response
url = "https://api.github.com/search/repositories"
url += "?q=language:python+stars:>10000"

headers = {"Accept": "application/vnd.github.v3+json"}  # Use third version of API
r = requests.get(url, headers=headers)
print(f"Status code: {r.status_code}")

# Process overall results
response_dict = r.json()
print(f"Complete results: {not response_dict['incomplete_results']}")

# Process repository information
repo_dicts = response_dict['items']
repo_links, stars, hover_texts = [], [], []
for repo_dict in repo_dicts:
# Turn repo names into active links.
    repo_name = repo_dict['name']
    repo_url = repo_dict['html_url']
    repo_link = f"<a href='{repo_url}'>{repo_name}</a>"
    repo_links.append(repo_link)

    stars.append(repo_dict['stargazers_count'])

    # Build hover texts.
    owner = repo_dict['owner']['login']
    description = repo_dict['description']
    hover_text = f"{owner}<br />{description}"
    hover_texts.append(hover_text)

# Make visualization.
title = "Most-Starred Python Projects on GitHub"
labels = {'x': 'Repository', 'y': 'Stars'}
fig = px.bar(x=repo_links, y=stars, title=title, labels=labels,
            hover_name=hover_texts)
fig.update_layout(title_font_size=28, xaxis_title_font_size=20,
                yaxis_title_font_size=20)

fig.update_traces(marker_color='SteelBlue', marker_opacity=0.6)

# Force Plotly to execute in a true browser environment
# Can change it back to normal but the hyperlinks will not work here
fig.show(renderer="browser")
# Out:
# Status code: 200
# Complete results: True

# %% [markdown]
# Now Using Hacker News API

# %%
import requests
import json
# Make an API call, and store the response.
url = "https://hacker-news.firebaseio.com/v0/item/31353677.json"
r = requests.get(url)
print(f"Status code: {r.status_code}")
# Explore the structure of the data.
response_dict = r.json()
response_string = json.dumps(response_dict, indent=4)
print(response_string)
# Out:
# Status code: 200
# {
#     "by": "sohkamyung",
#     "descendants": 307,
#     "id": 31353677,
#     "kids": [
#         31354987,
#         31354235,
#         31354040,
#         31358602,
#         31354201,
#         31354991,
#         31354315,
#         31353775,
#         31353925,
#         31354169,
#         31354273,
#         31354437,
#         31356902,
#         31358694,
#         31363418,
#         31353862,
#         31357186,
#         31356379,
#         31356826,
#         31355085,
#         31369435,
#         31357936,
#         31354142,
#         31354213,
#         31356311,
#         31357865,
#         31353929,
#         31364954,
#         31354621,
#         31356002,
#         31356407,
#         31355491,
#         31359235,
#         31356053,
#         31354347,
#         31355326,
#         31354703,
#         31353802
#     ],
#     "score": 786,
#     "time": 1652361401,
# ...

# %%
from operator import itemgetter
import requests

# Make an API call and check the response.
url = "https://hacker-news.firebaseio.com/v0/topstories.json"
r = requests.get(url)
print(f"Status code: {r.status_code}")

# Process information about each submission.
submission_ids = r.json()
submission_dicts = []

for submission_id in submission_ids[:5]:
    # Make a new API call for each submission.
    url = f"https://hacker-news.firebaseio.com/v0/item/{submission_id}.json"
    # Example link: https://hacker-news.firebaseio.com/v0/item/48511072.json
    
    r = requests.get(url)
    print(f"id: {submission_id}\tstatus: {r.status_code}")
    response_dict = r.json()
    
    # Build a dictionary for each article.
    submission_dict = {
    'title': response_dict['title'],
    'hn_link': f"https://news.ycombinator.com/item?id={submission_id}",
    'comments': response_dict['descendants'],
    }
    submission_dicts.append(submission_dict)
    
submission_dicts = sorted(submission_dicts, key=itemgetter('comments'),
reverse=True)

for submission_dict in submission_dicts:
    print(f"\nTitle: {submission_dict['title']}")
    print(f"Discussion link: {submission_dict['hn_link']}")
    print(f"Comments: {submission_dict['comments']}")
# Out:
# Status code: 200
# id: 48517377	status: 200
# id: 48516504	status: 200
# id: 48515336	status: 200
# id: 48516710	status: 200
# id: 48517199	status: 200
#
# Title: AI OSS tool repo goes archived over night after raising $7.3M Seed
# Discussion link: https://news.ycombinator.com/item?id=48516504
# Comments: 85
#
# Title: A low-carbon computing platform from your retired phones
# Discussion link: https://news.ycombinator.com/item?id=48515336
# Comments: 75
#
# Title: US bans differential privacy in Census data
# Discussion link: https://news.ycombinator.com/item?id=48517377
# Comments: 29
#
# Title: Introduction to the experience of rendering Arabic typography&its technical debt
# Discussion link: https://news.ycombinator.com/item?id=48516710
# Comments: 5
#
# Title: Treating pancreatic tumours may have revealed cancer's master switch
# Discussion link: https://news.ycombinator.com/item?id=48517199
# Comments: 2
